# %% [markdown]
# # AI - Natural Language Processing
# ## Part 2 - Functionalize NLP for entities

# %% [markdown]
# # ONLY IF NEEDED

# %% [markdown]
# ## Step 1. Install Spacy
#
# If this first time ever using spacy on this computer, you must first do either the ```!conda install``` or ```!pip install```:

# %% [markdown]
# ### TURN OFF FOR COLAB
# Run for ANACONDA

# %%
conda install -c conda-forge spacy

# %% [markdown]
# #### Which language model is best for you?
# <a href="https://spacy.io/usage/models">https://spacy.io/usage/models</a>

# %% [markdown]
# ## Step 2. Install language model

# %% [markdown]
# ### ANACONDA ONLY

# %%
conda install -c conda-forge spacy-model-en_core_web_sm

# %% [markdown]
# # Import libraries

# %%
import spacy
import pandas as pd
import glob

# %% [markdown]
# ## Import hearings
# Download <a href="https://drive.google.com/file/d/1EUYLeHpHAAW2MGsrT6_jov9cJ-IuDLg-/view?usp=sharing">this senate hearing</a> and turn it into a spacy doc.
#
# Create a spreadsheet with columns for the entity, the label, and its meaning.
#
# (remember, you will have to also tap elements from weeks' lessons to accomplish this)

# %%
# importing text file through `glob`

senate_hearing = glob.glob("senate-hearing.txt")
senate_hearing
# Out:
# ['senate-hearing.txt']

# %%
# reading file

with open(senate_hearing[0], "r") as my_text:
    print(my_text.read(200)) # gives you the first 200 characters
    text_file = my_text.read() # saves the entire thing in a variable
# Out:
# [Senate Hearing 118-22]
# [From the U.S. Government Publishing Office]
#
#
#                                                         S. Hrg. 118-22
#
#                    IMPLEMENTING IIJA: PERSPECTIVES ON

# %%
# importing nlp language

import en_core_web_trf

# %%
# creating nlp pipeline

nlp = spacy.load("en_core_web_trf")
# Out:
# /Users/cmgs/.pyenv/versions/3.11.8/lib/python3.11/site-packages/transformers/utils/generic.py:441: FutureWarning: `torch.utils._pytree._register_pytree_node` is deprecated. Please use `torch.utils._pytree.register_pytree_node` instead.
#   _torch_pytree._register_pytree_node(
# /Users/cmgs/.pyenv/versions/3.11.8/lib/python3.11/site-packages/transformers/utils/generic.py:309: FutureWarning: `torch.utils._pytree._register_pytree_node` is deprecated. Please use `torch.utils._pytree.register_pytree_node` instead.
#   _torch_pytree._register_pytree_node(
# /Users/cmgs/.pyenv/versions/3.11.8/lib/python3.11/site-packages/thinc/shims/pytorch.py:261: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model.load_state_dict(torch.load(filelike, map_location=device))

# %%
# creating spacy doc

doc = nlp(text_file)

# %%
# lists to hold items we need from the spacy doc

entities = [ word.text.strip() for word in doc.ents ]
labels = [ word.label_ for word in doc.ents ]
meanings = [ spacy.explain(word.label_) for word in doc.ents ]

# %%
# converting separate lists into dictionary

hearing_data = [ {"entity": entity, "label": label, "explanation": meaning} for (entity, label, meaning) in zip(entities, labels, meanings) ]
hearing_data
# Out:
# [{'entity': 'MARCH 15',
#   'label': 'DATE',
#   'explanation': 'Absolute or relative dates or periods'},
#  {'entity': 'the Committee on Environment and Public Works',
#   'label': 'ORG',
#   'explanation': 'Companies, agencies, institutions, etc.'},
#  {'entity': 'the World Wide Web',
#   'label': 'ORG',
#   'explanation': 'Companies, agencies, institutions, etc.'},
#  {'entity': 'WASHINGTON',
#   'label': 'GPE',
#   'explanation': 'Countries, cities, states'},
#  {'entity': 'EIGHTEENTH',
#   'label': 'DATE',
#   'explanation': 'Absolute or relative dates or periods'},
#  {'entity': 'THOMAS R. CARPER',
#   'label': 'PERSON',
#   'explanation': 'People, including fictional'},
#  {'entity': 'Delaware',
#   'label': 'GPE',
#   'explanation': 'Countries, cities, states'},
#  {'entity': 'SHELLEY MOORE CAPITO',
#   'label': 'PERSON',
#   'explanation': 'People, including fictional'},
#  {'entity': 'West Virginia',
#   'label': 'GPE',
#   'explanation': 'Countries, cities, states'},
#  {'entity': 'BENJAMIN L. CARDIN',
#   'label': 'PERSON',
#   'explanation': 'People, including fictional'},
#  {'entity': 'Maryland',
#   'label': 'GPE',
#   'explanation': 'Countries, cities, states'},
#  {'entity': 'KEVIN CRAMER',
#   'label': 'PERSON',
#   'explanation': 'People, including fictional'},
#  {'entity': 'North Dakota',
#   'label': 'GPE',
#   'explanation': 'Countries, cities, states'},
#  {'entity': 'BERNARD SANDERS',
#   'label': 'PERSON',
#   'explanation': 'People, including fictional'},
#  {'entity': 'Vermont',
#   'label': 'GPE',
#   'explanation': 'Countries, cities, states'},
#  {'entity': 'CYNTHIA M. LUMMIS',
#   'label': 'PERSON',
#   'explanation': 'People, including fictional'},
#  {'entity': 'Wyoming',
#   'label': 'GPE',
#   'explanation': 'Countries, cities, states'},
#  {'entity': 'SHELDON WHITEHOUSE',
#   'label': 'PERSON',
#   'explanation': 'People, including fictional'},
#  {'entity': 'Rhode Island',
#   'label': 'GPE',
#   'explanation': 'Countries, cities, states'},
#  {'entity': 'MARKWAYNE MULLIN',
#   'label': 'PERSON',
#   'explanation': 'People, including fictional'},
#  {'entity': 'Oklahoma',
#   'label': 'GPE',
#   'explanation': 'Countries, cities, states'},
#  {'entity': 'JEFF MERKLEY',
#   'label': 'PERSON',
#   'explanation': 'People, including fictional'},
#  {'entity': 'Oregon',
#   'label': 'GPE',
#   'explanation': 'Countries, cities, states'},
#  {'entity': 'PETE RICKETTS',
#   'label': 'PERSON',
#   'explanation': 'People, including fictional'},
#  {'entity': 'Nebraska',
#   'label': 'GPE',
#   'explanation': 'Countries, cities, states'},
#  {'entity': 'EDWARD J. MARKEY',
#   'label': 'PERSON',
#   'explanation': 'People, including fictional'},
#  {'entity': 'Massachusetts',
#   'label': 'GPE',
#   'explanation': 'Countries, cities, states'},
#  {'entity': 'JOHN BOOZMAN',
#   'label': 'PERSON',
#   'explanation': 'People, including fictional'},
#  {'entity': 'Arkansas',
#   'label': 'GPE',
#   'explanation': 'Countries, cities, states'},
#  {'entity': 'DEBBIE STABENOW',
#   'label': 'PERSON',
#   'explanation': 'People, including fictional'},
#  {'entity': 'Michigan',
#   'label': 'GPE',
#   'explanation': 'Countries, cities, states'},
#  {'entity': 'ROGER WICKER',
#   'label': 'PERSON',
#   'explanation': 'People, including fictional'},
#  {'entity': 'Mississippi',
#   'label': 'GPE',
#   'explanation': 'Countries, cities, states'},
#  {'entity': 'MARK KELLY',
#   'label': 'PERSON',
#   'explanation': 'People, including fictional'},
#  {'entity': 'Arizona',
#   'label': 'GPE',
#   'explanation': 'Countries, cities, states'},
#  {'entity': 'DAN SULLIVAN',
#   'label': 'PERSON',
#   'explanation': 'People, including fictional'},
#  {'entity': 'Alaska',
#   'label': 'GPE',
#   'explanation': 'Countries, cities, states'},
#  {'entity': 'ALEX PADILLA',
#   'label': 'PERSON',
#   'explanation': 'People, including fictional'},
#  {'entity': 'California',
#   'label': 'GPE',
#   'explanation': 'Countries, cities, states'},
#  {'entity': 'LINDSEY O. GRAHAM',
#   'label': 'PERSON',
#   'explanation': 'People, including fictional'},
#  {'entity': 'South Carolina',
#   'label': 'GPE',
#   'explanation': 'Countries, cities, states'},
#  {'entity': 'JOHN FETTERMAN',
#   'label': 'PERSON',
#   'explanation': 'People, including fictional'},
#  {'entity': 'Pennsylvania',
#   'label': 'GPE',
#   'explanation': 'Countries, cities, states'},
#  {'entity': 'Courtney Taylor',
#   'label': 'PERSON',
#   'explanation': 'People, including fictional'},
#  {'entity': 'Democratic',
#   'label': 'NORP',
#   'explanation': 'Nationalities or religious or political groups'},
#  {'entity': 'Adam Tomlinson',
#   'label': 'PERSON',
#   'explanation': 'People, including fictional'},
#  {'entity': 'Republican',
#   'label': 'NORP',
#   'explanation': 'Nationalities or religious or political groups'},
#  {'entity': 'C O N T E',
#   'label': 'ORG',
#   'explanation': 'Companies, agencies, institutions, etc.'},
#  {'entity': 'MARCH 15, 2023',
#   'label': 'DATE',
#   'explanation': 'Absolute or relative dates or periods'},
#  {'entity': 'Carper',
#   'label': 'PERSON',
#   'explanation': 'People, including fictional'},
#  {'entity': 'Thomas R.',
#   'label': 'PERSON',
#   'explanation': 'People, including fictional'},
#  {'entity': 'U.S.',
#   'label': 'GPE',
#   'explanation': 'Countries, cities, states'},
#  {'entity': 'Delaware',
#   'label': 'GPE',
#   'explanation': 'Countries, cities, states'},
#  {'entity': '1',
#   'label': 'CARDINAL',
#   'explanation': 'Numerals that do not fall under another type'},
#  {'entity': 'Capito',
#   'label': 'PERSON',
#   'explanation': 'People, including fictional'},
#  {'entity': 'Shelley Moore',
#   'label': 'PERSON',
#   'explanation': 'People, including fictional'},
#  {'entity': 'U.S.',
#   'label': 'GPE',
#   'explanation': 'Countries, cities, states'},
#  {'entity': 'West',
#   'label': 'GPE',
#   'explanation': 'Countries, cities, states'},
#  {'entity': '3',
#   'label': 'CARDINAL',
#   'explanation': 'Numerals that do not fall under another type'},
#  {'entity': 'Fox',
#   'label': 'PERSON',
#   'explanation': 'People, including fictional'},
#  {'entity': 'Radhika',
#   'label': 'PERSON',
#   'explanation': 'People, including fictional'},
#  {'entity': 'Office of Water',
#   'label': 'ORG',
#   'explanation': 'Companies, agencies, institutions, etc.'},
#  {'entity': 'Environmental Protection Agency',
#   'label': 'ORG',
#   'explanation': 'Companies, agencies, institutions, etc.'},
#  {'entity': '6',
#   'label': 'CARDINAL',
#   'explanation': 'Numerals that do not fall under another type'},
#  {'entity': '9',
#   'label': 'CARDINAL',
#   'explanation': 'Numerals that do not fall under another type'},
#  {'entity': 'Carper',
#   'label': 'PERSON',
#   'explanation': 'People, including fictional'},
#  {'entity': '18',
#   'label': 'CARDINAL',
#   'explanation': 'Numerals that do not fall under another type'},
#  {'entity': 'Fetterman',
#   'label': 'PERSON',
#   'explanation': 'People, including fictional'},
#  {'entity': '23',
#   'label': 'CARDINAL',
#   'explanation': 'Numerals that do not fall under another type'},
#  {'entity': 'Capito',
#   'label': 'PERSON',
#   'explanation': 'People, including fictional'},
#  {'entity': '25',
#   'label': 'CARDINAL',
#   'explanation': 'Numerals that do not fall under another type'},
#  {'entity': 'Cramer',
#   'label': 'PERSON',
#   'explanation': 'People, including fictional'},
#  {'entity': '28',
#   'label': 'CARDINAL',
#   'explanation': 'Numerals that do not fall under another type'},
#  {'entity': 'Lummis',
#   'label': 'PERSON',
#   'explanation': 'People, including fictional'},
#  {'entity': '30',
#   'label': 'CARDINAL',
#   'explanation': 'Numerals that do not fall under another type'},
#  {'entity': 'Mullin',
#   'label': 'PERSON',
#   'explanation': 'People, including fictional'},
#  {'entity': '30',
#   'label': 'CARDINAL',
#   'explanation': 'Numerals that do not fall under another type'},
#  {'entity': 'Sullivan',
#   'label': 'PERSON',
#   'explanation': 'People, including fictional'},
#  {'entity': '32',
#   'label': 'CARDINAL',
#   'explanation': 'Numerals that do not fall under another type'},
#  {'entity': 'Hayman',
#   'label': 'PERSON',
#   'explanation': 'People, including fictional'},
#  {'entity': 'Randy E.',
#   'label': 'PERSON',
#   'explanation': 'People, including fictional'},
#  {'entity': 'Philadelphia Water',
#   'label': 'ORG',
#   'explanation': 'Companies, agencies, institutions, etc.'},
#  {'entity': '70',
#   'label': 'CARDINAL',
#   'explanation': 'Numerals that do not fall under another type'},
#  {'entity': '73',
#   'label': 'CARDINAL',
#   'explanation': 'Numerals that do not fall under another type'},
#  {'entity': 'Carper',
#   'label': 'PERSON',
#   'explanation': 'People, including fictional'},
#  {'entity': '82',
#   'label': 'CARDINAL',
#   'explanation': 'Numerals that do not fall under another type'},
#  {'entity': 'Sigmund',
#   'label': 'PERSON',
#   'explanation': 'People, including fictional'},
#  {'entity': 'Thomas W.',
#   'label': 'PERSON',
#   'explanation': 'People, including fictional'},
#  {'entity': 'National Association of Clean \n  Water Agencies',
#   'label': 'ORG',
#   'explanation': 'Companies, agencies, institutions, etc.'},
#  {'entity': 'NEW Water',
#   'label': 'ORG',
#   'explanation': 'Companies, agencies, institutions, etc.'},
#  {'entity': '90',
#   'label': 'CARDINAL',
#   'explanation': 'Numerals that do not fall under another type'},
#  {'entity': '93',
#   'label': 'CARDINAL',
#   'explanation': 'Numerals that do not fall under another type'},
#  {'entity': 'Carper',
#   'label': 'PERSON',
#   'explanation': 'People, including fictional'},
#  {'entity': '161',
#   'label': 'CARDINAL',
#   'explanation': 'Numerals that do not fall under another type'},
#  {'entity': 'Emery',
#   'label': 'PERSON',
#   'explanation': 'People, including fictional'},
#  {'entity': 'Katheryn D.',
#   'label': 'PERSON',
#   'explanation': 'People, including fictional'},
#  {'entity': 'Division of Water and Waste',
#   'label': 'ORG',
#   'explanation': 'Companies, agencies, institutions, etc.'},
#  {'entity': 'West Virginia',
#   'label': 'GPE',
#   'explanation': 'Countries, cities, states'},
#  {'entity': 'Department of Environmental',
#   'label': 'ORG',
#   'explanation': 'Companies, agencies, institutions, etc.'},
#  {'entity': '166',
#   'label': 'CARDINAL',
#   'explanation': 'Numerals that do not fall under another type'},
#  {'entity': '168',
#   'label': 'CARDINAL',
#   'explanation': 'Numerals that do not fall under another type'},
#  {'entity': 'Carper',
#   'label': 'PERSON',
#   'explanation': 'People, including fictional'},
#  {'entity': '175',
#   'label': 'CARDINAL',
#   'explanation': 'Numerals that do not fall under another type'},
#  {'entity': 'Charles Schumer',
#   'label': 'PERSON',
#   'explanation': 'People, including fictional'},
#  {'entity': 'the American \n  Sustainable Business Network',
#   'label': 'ORG',
#   'explanation': 'Companies, agencies, institutions, etc.'},
#  {'entity': 'March 6, 2023',
#   'label': 'DATE',
#   'explanation': 'Absolute or relative dates or periods'},
#  {'entity': '45',
#   'label': 'CARDINAL',
#   'explanation': 'Numerals that do not fall under another type'},
#  {'entity': 'Carper',
#   'label': 'PERSON',
#   'explanation': 'People, including fictional'},
#  {'entity': 'Capito',
#   'label': 'PERSON',
#   'explanation': 'People, including fictional'},
#  {'entity': 'the California \n  Association of Sanitation Agencies',
#   'label': 'ORG',
#   'explanation': 'Companies, agencies, institutions, etc.'},
#  {'entity': 'March 15, 2023',
#   'label': 'DATE',
#   'explanation': 'Absolute or relative dates or periods'},
#  {'entity': '188',
#   'label': 'CARDINAL',
#   'explanation': 'Numerals that do not fall under another type'},
#  {'entity': 'Carper',
#   'label': 'PERSON',
#   'explanation': 'People, including fictional'},
#  {'entity': 'Capito',
#   'label': 'PERSON',
#   'explanation': 'People, including fictional'},
#  {'entity': 'American Rivers',
#   'label': 'ORG',
#   'explanation': 'Companies, agencies, institutions, etc.'},
#  {'entity': 'March \n  14, 2023',
#   'label': 'DATE',
#   'explanation': 'Absolute or relative dates or periods'},
#  {'entity': '192',
#   'label': 'CARDINAL',
#   'explanation': 'Numerals that do not fall under another type'},
#  {'entity': 'the Council of Infrastructure Financing Authorities',
#   'label': 'ORG',
#   'explanation': 'Companies, agencies, institutions, etc.'},
#  {'entity': 'March 15, 2023',
#   'label': 'DATE',
#   'explanation': 'Absolute or relative dates or periods'},
#  {'entity': '220',
#   'label': 'CARDINAL',
#   'explanation': 'Numerals that do not fall under another type'},
#  {'entity': 'IIJA:',
#   'label': 'LAW',
#   'explanation': 'Named documents made into laws.'},
#  {'entity': 'WEDNESDAY, MARCH 15, 2023',
#   'label': 'DATE',
#   'explanation': 'Absolute or relative dates or periods'},
#  {'entity': 'U.S. Senate',
#   'label': 'ORG',
#   'explanation': 'Companies, agencies, institutions, etc.'},
#  {'entity': 'Committee on Environment and Public Works',
#   'label': 'ORG',
#   'explanation': 'Companies, agencies, institutions, etc.'},
#  {'entity': 'Washington',
#   'label': 'GPE',
#   'explanation': 'Countries, cities, states'},
#  {'entity': 'DC', 'label': 'GPE', 'explanation': 'Countries, cities, states'},
#  {'entity': '10:05 a.m.',
#   'label': 'TIME',
#   'explanation': 'Times smaller than a day'},
#  {'entity': '406',
#   'label': 'CARDINAL',
#   'explanation': 'Numerals that do not fall under another type'},
#  {'entity': 'Dirksen Senate Office Building',
#   'label': 'FAC',
#   'explanation': 'Buildings, airports, highways, bridges, etc.'},
#  {'entity': 'Thomas R. Carper',
#   'label': 'PERSON',
#   'explanation': 'People, including fictional'},
#  {'entity': 'Carper',
#   'label': 'PERSON',
#   'explanation': 'People, including fictional'},
#  {'entity': 'Capito',
#   'label': 'PERSON',
#   'explanation': 'People, including fictional'},
#  {'entity': 'Cardin',
#   'label': 'PERSON',
#   'explanation': 'People, including fictional'},
#  {'entity': 'Markey',
#   'label': 'PERSON',
#   'explanation': 'People, including fictional'},
#  {'entity': 'Kelly',
#   'label': 'PERSON',
#   'explanation': 'People, including fictional'},
#  {'entity': 'Cramer',
#   'label': 'PERSON',
#   'explanation': 'People, including fictional'},
#  {'entity': 'Lummis',
#   'label': 'PERSON',
#   'explanation': 'People, including fictional'},
#  {'entity': 'Sullivan',
#   'label': 'PERSON',
#   'explanation': 'People, including fictional'},
#  {'entity': 'Ricketts',
#   'label': 'PERSON',
#   'explanation': 'People, including fictional'},
#  {'entity': 'THOMAS R. CARPER',
#   'label': 'PERSON',
#   'explanation': 'People, including fictional'},
#  {'entity': 'U.S.',
#   'label': 'GPE',
#   'explanation': 'Countries, cities, states'},
#  {'entity': 'THE STATE OF DELAWARE',
#   'label': 'GPE',
#   'explanation': 'Countries, cities, states'},
#  {'entity': 'Carper',
#   'label': 'PERSON',
#   'explanation': 'People, including fictional'},
#  {'entity': 'morning',
#   'label': 'TIME',
#   'explanation': 'Times smaller than a day'},
#  {'entity': 'today',
#   'label': 'DATE',
#   'explanation': 'Absolute or relative dates or periods'},
#  {'entity': 'the Bipartisan \nInfrastructure Law',
#   'label': 'LAW',
#   'explanation': 'Named documents made into laws.'},
#  {'entity': 'millions',
#   'label': 'CARDINAL',
#   'explanation': 'Numerals that do not fall under another type'},
#  {'entity': 'today',
#   'label': 'DATE',
#   'explanation': 'Absolute or relative dates or periods'},
#  {'entity': 'Radhika Fox',
#   'label': 'PERSON',
#   'explanation': 'People, including fictional'},
#  {'entity': 'EPA',
#   'label': 'ORG',
#   'explanation': 'Companies, agencies, institutions, etc.'},
#  {'entity': 'Office of Water',
#   'label': 'ORG',
#   'explanation': 'Companies, agencies, institutions, etc.'},
#  {'entity': 'Capito',
#   'label': 'PERSON',
#   'explanation': 'People, including fictional'},
#  {'entity': 'this day',
#   'label': 'DATE',
#   'explanation': 'Absolute or relative dates or periods'},
#  {'entity': 'Yesterday',
#   'label': 'DATE',
#   'explanation': 'Absolute or relative dates or periods'},
#  {'entity': 'Biden',
#   'label': 'PERSON',
#   'explanation': 'People, including fictional'},
#  {'entity': 'some 20 years',
#   'label': 'DATE',
#   'explanation': 'Absolute or relative dates or periods'},
#  {'entity': 'West Virginia',
#   'label': 'GPE',
#   'explanation': 'Countries, cities, states'},
#  {'entity': 'Delaware',
#   'label': 'GPE',
#   'explanation': 'Countries, cities, states'},
#  {'entity': '48',
#   'label': 'CARDINAL',
#   'explanation': 'Numerals that do not fall under another type'},
#  {'entity': 'Regan',
#   'label': 'PERSON',
#   'explanation': 'People, including fictional'},
#  {'entity': 'Fox',
#   'label': 'PERSON',
#   'explanation': 'People, including fictional'},
#  {'entity': 'EPA',
#   'label': 'ORG',
#   'explanation': 'Companies, agencies, institutions, etc.'},
#  {'entity': '2024',
#   'label': 'DATE',
#   'explanation': 'Absolute or relative dates or periods'},
#  {'entity': 'last week',
#   'label': 'DATE',
#   'explanation': 'Absolute or relative dates or periods'},
#  {'entity': 'more than $12 billion',
#   'label': 'MONEY',
#   'explanation': 'Monetary values, including unit'},
#  {'entity': 'EPA',
#   'label': 'ORG',
#   'explanation': 'Companies, agencies, institutions, etc.'},
#  {'entity': '$1.9 billion',
#   'label': 'MONEY',
#   'explanation': 'Monetary values, including unit'},
#  {'entity': '19',
#   'label': 'PERCENT',
#   'explanation': 'Percentage, including "%"'},
#  {'entity': '2023',
#   'label': 'DATE',
#   'explanation': 'Absolute or relative dates or periods'},
#  {'entity': 'More than $4',
#   'label': 'MONEY',
#   'explanation': 'Monetary values, including unit'},
#  {'entity': 'an additional $219 million',
#   'label': 'MONEY',
#   'explanation': 'Monetary values, including unit'},
#  {'entity': 'Committee',
#   'label': 'ORG',
#   'explanation': 'Companies, agencies, institutions, etc.'},
#  {'entity': 'the \nBipartisan Infrastructure Law',
#   'label': 'LAW',
#   'explanation': 'Named documents made into laws.'},
#  {'entity': 'today',
#   'label': 'DATE',
#   'explanation': 'Absolute or relative dates or periods'},
#  {'entity': 'the Bipartisan Infrastructure Law',
#   'label': 'LAW',
#   'explanation': 'Named documents made into laws.'},
#  {'entity': 'Democrats',
#   'label': 'NORP',
#   'explanation': 'Nationalities or religious or political groups'},
#  {'entity': 'Republicans',
#   'label': 'NORP',
#   'explanation': 'Nationalities or religious or political groups'},
#  {'entity': 'today',
#   'label': 'DATE',
#   'explanation': 'Absolute or relative dates or periods'},
#  {'entity': 'West Virginia',
#   'label': 'GPE',
#   'explanation': 'Countries, cities, states'},
#  {'entity': 'West Virginia',
#   'label': 'GPE',
#   'explanation': 'Countries, cities, states'},
#  {'entity': 'West Virginia',
#   'label': 'GPE',
#   'explanation': 'Countries, cities, states'},
#  {'entity': 'Carper',
#   'label': 'PERSON',
#   'explanation': 'People, including fictional'},
#  {'entity': 'Committee',
#   'label': 'ORG',
#   'explanation': 'Companies, agencies, institutions, etc.'},
#  {'entity': 'Raleigh County',
#   'label': 'GPE',
#   'explanation': 'Countries, cities, states'},
#  {'entity': 'West Virginia',
#   'label': 'GPE',
#   'explanation': 'Countries, cities, states'},
#  {'entity': 'Matthew 25',
#   'label': 'LAW',
#   'explanation': 'Named documents made into laws.'},
#  {'entity': 'Americans',
#   'label': 'NORP',
#   'explanation': 'Nationalities or religious or political groups'},
#  {'entity': 'Beckley',
#   'label': 'GPE',
#   'explanation': 'Countries, cities, states'},
#  {'entity': '2',
#   'label': 'CARDINAL',
#   'explanation': 'Numerals that do not fall under another type'},
#  {'entity': 'those 6 \nyears',
#   'label': 'DATE',
#   'explanation': 'Absolute or relative dates or periods'},
#  {'entity': 'my first 6 years',
#   'label': 'DATE',
#   'explanation': 'Absolute or relative dates or periods'},
#  {'entity': 'Beaver',
#   'label': 'GPE',
#   'explanation': 'Countries, cities, states'},
#  {'entity': 'Beaver',
#   'label': 'GPE',
#   'explanation': 'Countries, cities, states'},
#  {'entity': 'Beckley',
#   'label': 'GPE',
#   'explanation': 'Countries, cities, states'},
#  {'entity': 'Beaver',
#   'label': 'LOC',
#   'explanation': 'Non-GPE locations, mountain ranges, bodies of water'},
#  {'entity': 'Beaver Creek',
#   'label': 'LOC',
#   'explanation': 'Non-GPE locations, mountain ranges, bodies of water'},
#  {'entity': 'Beaver Creek',
#   'label': 'LOC',
#   'explanation': 'Non-GPE locations, mountain ranges, bodies of water'},
#  {'entity': 'West Virginia',
#   'label': 'GPE',
#   'explanation': 'Countries, cities, states'},
#  {'entity': 'the years',
#   'label': 'DATE',
#   'explanation': 'Absolute or relative dates or periods'},
#  {'entity': 'Capito',
#   'label': 'PERSON',
#   'explanation': 'People, including fictional'},
#  {'entity': 'Cardin',
#   'label': 'PERSON',
#   'explanation': 'People, including fictional'},
#  {'entity': 'Lummis',
#   'label': 'PERSON',
#   'explanation': 'People, including fictional'},
#  {'entity': 'Duckworth',
#   'label': 'PERSON',
#   'explanation': 'People, including fictional'},
#  {'entity': 'Cramer',
#   'label': 'PERSON',
#   'explanation': 'People, including fictional'},
#  {'entity': 'Committee',
#   'label': 'ORG',
#   'explanation': 'Companies, agencies, institutions, etc.'},
#  {'entity': 'Committee',
#   'label': 'ORG',
#   'explanation': 'Companies, agencies, institutions, etc.'},
#  {'entity': 'the \nDrinking Water and Wastewater Infrastructure Act',
#   'label': 'LAW',
#   'explanation': 'Named documents made into laws.'},
#  {'entity': 'EPA',
#   'label': 'ORG',
#   'explanation': 'Companies, agencies, institutions, etc.'},
#  {'entity': 'State Revolving Funds',
#   'label': 'LAW',
#   'explanation': 'Named documents made into laws.'},
#  {'entity': 'State',
#   'label': 'ORG',
#   'explanation': 'Companies, agencies, institutions, etc.'},
#  {'entity': 'America',
#   'label': 'GPE',
#   'explanation': 'Countries, cities, states'},
#  {'entity': 'Committee',
#   'label': 'ORG',
#   'explanation': 'Companies, agencies, institutions, etc.'},
#  {'entity': 'Senate',
#   'label': 'ORG',
#   'explanation': 'Companies, agencies, institutions, etc.'},
#  {'entity': '89',
#   'label': 'CARDINAL',
#   'explanation': 'Numerals that do not fall under another type'},
#  {'entity': '2',
#   'label': 'CARDINAL',
#   'explanation': 'Numerals that do not fall under another type'},
#  {'entity': 'American',
#   'label': 'NORP',
#   'explanation': 'Nationalities or religious or political groups'},
#  {'entity': 'Committee',
#   'label': 'ORG',
#   'explanation': 'Companies, agencies, institutions, etc.'},
#  {'entity': 'Committee',
#   'label': 'ORG',
#   'explanation': 'Companies, agencies, institutions, etc.'},
#  {'entity': 'the Bipartisan Infrastructure Law',
#   'label': 'LAW',
#   'explanation': 'Named documents made into laws.'},
#  {'entity': 'Biden',
#   'label': 'PERSON',
#   'explanation': 'People, including fictional'},
#  {'entity': 'November 2021',
#   'label': 'DATE',
#   'explanation': 'Absolute or relative dates or periods'},
#  {'entity': 'a happy day',
#   'label': 'DATE',
#   'explanation': 'Absolute or relative dates or periods'},
#  {'entity': 'The Bipartisan Infrastructure Law',
#   'label': 'LAW',
#   'explanation': 'Named documents made into laws.'},
#  {'entity': 'an unprecedented \n$55 billion',
#   'label': 'MONEY',
#   'explanation': 'Monetary values, including unit'},
#  {'entity': '$55 billion',
#   'label': 'MONEY',
#   'explanation': 'Monetary values, including unit'},
#  {'entity': 'billion',
#   'label': 'CARDINAL',
#   'explanation': 'Numerals that do not fall under another type'},
#  {'entity': 'EPA',
#   'label': 'ORG',
#   'explanation': 'Companies, agencies, institutions, etc.'},
#  {'entity': 'American',
#   'label': 'NORP',
#   'explanation': 'Nationalities or religious or political groups'},
#  {'entity': 'Today',
#   'label': 'DATE',
#   'explanation': 'Absolute or relative dates or periods'},
#  {'entity': 'Bipartisan Infrastructure \nLaw',
#   'label': 'LAW',
#   'explanation': 'Named documents made into laws.'},
#  {'entity': 'today',
#   'label': 'DATE',
#   'explanation': 'Absolute or relative dates or periods'},
#  {'entity': 'Capito',
#   'label': 'PERSON',
#   'explanation': 'People, including fictional'},
#  {'entity': 'Capito',
#   'label': 'PERSON',
#   'explanation': 'People, including fictional'},
#  {'entity': 'SHELLEY MOORE CAPITO',
#   'label': 'PERSON',
#   'explanation': 'People, including fictional'},
#  {'entity': 'U.S.',
#   'label': 'GPE',
#   'explanation': 'Countries, cities, states'},
#  {'entity': 'THE STATE OF WEST VIRGINIA',
#   'label': 'GPE',
#   'explanation': 'Countries, cities, states'},
#  {'entity': 'Capito',
#   'label': 'PERSON',
#   'explanation': 'People, including fictional'},
#  {'entity': 'today',
#   'label': 'DATE',
#   'explanation': 'Absolute or relative dates or periods'},
#  {'entity': 'Fox',
#   'label': 'PERSON',
#   'explanation': 'People, including fictional'},
#  {'entity': 'today',
#   'label': 'DATE',
#   'explanation': 'Absolute or relative dates or periods'},
#  {'entity': 'many',
#   'label': 'DATE',
#   'explanation': 'Absolute or relative dates or periods'},
#  {'entity': 'Today',
#   'label': 'DATE',
#   'explanation': 'Absolute or relative dates or periods'},
#  {'entity': 'Americans',
#   'label': 'NORP',
#   'explanation': 'Nationalities or religious or political groups'},
#  {'entity': 'Committee',
#   'label': 'ORG',
#   'explanation': 'Companies, agencies, institutions, etc.'},
#  {'entity': 'Congress',
#   'label': 'ORG',
#   'explanation': 'Companies, agencies, institutions, etc.'},
#  {'entity': 'America',
#   'label': 'GPE',
#   'explanation': 'Countries, cities, states'},
#  {'entity': 'The DWWIA',
#   'label': 'LAW',
#   'explanation': 'Named documents made into laws.'},
#  {'entity': 'Committee',
#   'label': 'ORG',
#   'explanation': 'Companies, agencies, institutions, etc.'},
#  {'entity': 'the Infrastructure Investment and Jobs Act',
#   'label': 'LAW',
#   'explanation': 'Named documents made into laws.'},
#  {'entity': 'IIJA',
#   'label': 'LAW',
#   'explanation': 'Named documents made into laws.'},
#  {'entity': 'IIJA',
#   'label': 'ORG',
#   'explanation': 'Companies, agencies, institutions, etc.'},
#  {'entity': '$55 billion',
#   'label': 'MONEY',
#   'explanation': 'Monetary values, including unit'},
#  {'entity': 'States',
#   'label': 'GPE',
#   'explanation': 'Countries, cities, states'},
#  {'entity': 'IIJA',
#   'label': 'ORG',
#   'explanation': 'Companies, agencies, institutions, etc.'},
#  {'entity': 'EPA',
#   'label': 'ORG',
#   'explanation': 'Companies, agencies, institutions, etc.'},
#  {'entity': 'Congress',
#   'label': 'ORG',
#   'explanation': 'Companies, agencies, institutions, etc.'},
#  {'entity': 'States',
#   'label': 'ORG',
#   'explanation': 'Companies, agencies, institutions, etc.'},
#  {'entity': 'Federal',
#   'label': 'ORG',
#   'explanation': 'Companies, agencies, institutions, etc.'},
#  {'entity': 'the Safe Drinking Water Act',
#   'label': 'LAW',
#   'explanation': 'Named documents made into laws.'},
#  {'entity': 'Clean \nWater Act',
#   'label': 'LAW',
#   'explanation': 'Named documents made into laws.'},
#  {'entity': 'Congress',
#   'label': 'ORG',
#   'explanation': 'Companies, agencies, institutions, etc.'},
#  {'entity': 'Administration',
#   'label': 'ORG',
#   'explanation': 'Companies, agencies, institutions, etc.'},
#  {'entity': 'West Virginia',
#   'label': 'GPE',
#   'explanation': 'Countries, cities, states'},
#  {'entity': 'Congress',
#   'label': 'ORG',
#   'explanation': 'Companies, agencies, institutions, etc.'},
#  {'entity': 'DWWIA',
#   'label': 'LAW',
#   'explanation': 'Named documents made into laws.'},
#  {'entity': 'EPA',
#   'label': 'ORG',
#   'explanation': 'Companies, agencies, institutions, etc.'},
#  {'entity': 'West Virginia',
#   'label': 'GPE',
#   'explanation': 'Countries, cities, states'},
#  {'entity': 'Kathy Emery',
#   'label': 'PERSON',
#   'explanation': 'People, including fictional'},
#  {'entity': 'West Virginia',
#   'label': 'GPE',
#   'explanation': 'Countries, cities, states'},
#  {'entity': 'Raleigh County',
#   'label': 'GPE',
#   'explanation': 'Countries, cities, states'},
#  {'entity': 'Roy',
#   'label': 'PERSON',
#   'explanation': 'People, including fictional'},
#  {'entity': 'Taylor',
#   'label': 'PERSON',
#   'explanation': 'People, including fictional'},
#  {'entity': 'West \nVirginia University',
#   'label': 'GPE',
#   'explanation': 'Countries, cities, states'},
#  {'entity': 'West Virginia University',
#   'label': 'GPE',
#   'explanation': 'Countries, cities, states'},
#  {'entity': 'Carper',
#   'label': 'PERSON',
#   'explanation': 'People, including fictional'},
#  {'entity': 'Raleigh County',
#   'label': 'GPE',
#   'explanation': 'Countries, cities, states'},
#  {'entity': 'Raleigh',
#   'label': 'GPE',
#   'explanation': 'Countries, cities, states'},
#  {'entity': 'today',
#   'label': 'DATE',
#   'explanation': 'Absolute or relative dates or periods'},
#  {'entity': 'Delaware',
#   'label': 'GPE',
#   'explanation': 'Countries, cities, states'},
#  {'entity': 'The other day',
#   'label': 'DATE',
#   'explanation': 'Absolute or relative dates or periods'},
#  {'entity': 'States',
#   'label': 'GPE',
#   'explanation': 'Countries, cities, states'},
#  {'entity': 'first',
#   'label': 'ORDINAL',
#   'explanation': '"first", "second", etc.'},
#  {'entity': 'today',
#   'label': 'DATE',
#   'explanation': 'Absolute or relative dates or periods'},
#  {'entity': 'Radhika Fox',
#   'label': 'PERSON',
#   'explanation': 'People, including fictional'},
#  {'entity': "the U.S. Environmental Protection Agency's",
#   'label': 'ORG',
#   'explanation': 'Companies, agencies, institutions, etc.'},
#  {'entity': 'Office of Water',
#   'label': 'ORG',
#   'explanation': 'Companies, agencies, institutions, etc.'},
#  {'entity': 'Fox',
#   'label': 'PERSON',
#   'explanation': 'People, including fictional'},
#  {'entity': 'HON.',
#   'label': 'PERSON',
#   'explanation': 'People, including fictional'},
#  {'entity': 'RADHIKA FOX',
#   'label': 'PERSON',
#   'explanation': 'People, including fictional'},
#  {'entity': 'Fox',
#   'label': 'PERSON',
#   'explanation': 'People, including fictional'},
#  {'entity': 'morning',
#   'label': 'TIME',
#   'explanation': 'Times smaller than a day'},
#  {'entity': 'Carper',
#   'label': 'PERSON',
#   'explanation': 'People, including fictional'},
#  {'entity': 'Capito',
#   'label': 'PERSON',
#   'explanation': 'People, including fictional'},
#  {'entity': 'Committee',
#   'label': 'ORG',
#   'explanation': 'Companies, agencies, institutions, etc.'},
#  {'entity': 'EPA',
#   'label': 'ORG',
#   'explanation': 'Companies, agencies, institutions, etc.'},
#  {'entity': 'the Bipartisan Infrastructure Law',
#   'label': 'LAW',
#   'explanation': 'Named documents made into laws.'},
#  {'entity': 'Committee',
#   'label': 'ORG',
#   'explanation': 'Companies, agencies, institutions, etc.'},
#  {'entity': 'over $50 billion',
#   'label': 'MONEY',
#   'explanation': 'Monetary values, including unit'},
#  {'entity': 'America',
#   'label': 'GPE',
#   'explanation': 'Countries, cities, states'},
#  {'entity': 'a moment',
#   'label': 'TIME',
#   'explanation': 'Times smaller than a day'},
#  {'entity': 'EPA',
#   'label': 'ORG',
#   'explanation': 'Companies, agencies, institutions, etc.'},
#  {'entity': 'the \nOffice of Groundwater and Drinking Water',
#   'label': 'ORG',
#   'explanation': 'Companies, agencies, institutions, etc.'},
#  {'entity': 'today',
#   'label': 'DATE',
#   'explanation': 'Absolute or relative dates or periods'},
#  {'entity': 'the \nBipartisan Infrastructure Law',
#   'label': 'LAW',
#   'explanation': 'Named documents made into laws.'},
#  {'entity': 'American',
#   'label': 'NORP',
#   'explanation': 'Nationalities or religious or political groups'},
#  {'entity': 'EPA',
#   'label': 'ORG',
#   'explanation': 'Companies, agencies, institutions, etc.'},
#  {'entity': 'Congress',
#   'label': 'ORG',
#   'explanation': 'Companies, agencies, institutions, etc.'},
#  {'entity': 'about $43 billion',
#   'label': 'MONEY',
#   'explanation': 'Monetary values, including unit'},
#  {'entity': 'March 2022',
#   'label': 'DATE',
#   'explanation': 'Absolute or relative dates or periods'},
#  {'entity': 'EPA',
#   'label': 'ORG',
#   'explanation': 'Companies, agencies, institutions, etc.'},
#  {'entity': 'one',
#   'label': 'CARDINAL',
#   'explanation': 'Numerals that do not fall under another type'},
#  {'entity': 'States',
#   'label': 'GPE',
#   'explanation': 'Countries, cities, states'},
#  {'entity': 'America',
#   'label': 'GPE',
#   'explanation': 'Countries, cities, states'},
#  {'entity': 'States',
#   'label': 'GPE',
#   'explanation': 'Countries, cities, states'},
#  {'entity': 'State',
#   'label': 'ORG',
#   'explanation': 'Companies, agencies, institutions, etc.'},
#  {'entity': 'States',
#   'label': 'GPE',
#   'explanation': 'Countries, cities, states'},
#  {'entity': 'the Bipartisan Infrastructure \nLaw',
#   'label': 'LAW',
#   'explanation': 'Named documents made into laws.'},
#  {'entity': 'about 1 year later',
#   'label': 'DATE',
#   'explanation': 'Absolute or relative dates or periods'},
#  {'entity': '47',
#   'label': 'CARDINAL',
#   'explanation': 'Numerals that do not fall under another type'},
#  {'entity': 'six',
#   'label': 'CARDINAL',
#   'explanation': 'Numerals that do not fall under another type'},
#  {'entity': 'nearly $5 billion',
#   'label': 'MONEY',
#   'explanation': 'Monetary values, including unit'},
#  {'entity': 'the first year',
#   'label': 'DATE',
#   'explanation': 'Absolute or relative dates or periods'},
#  {'entity': 'a minute',
#   'label': 'TIME',
#   'explanation': 'Times smaller than a day'},
#  {'entity': 'Sierra Vista RV \nPark',
#   'label': 'FAC',
#   'explanation': 'Buildings, airports, highways, bridges, etc.'},
#  {'entity': 'Arizona',
#   'label': 'GPE',
#   'explanation': 'Countries, cities, states'},
#  {'entity': 'Sussex',
#   'label': 'GPE',
#   'explanation': 'Countries, cities, states'},
#  {'entity': 'Delaware',
#   'label': 'GPE',
#   'explanation': 'Countries, cities, states'},
#  {'entity': 'hundreds',
#   'label': 'CARDINAL',
#   'explanation': 'Numerals that do not fall under another type'},
#  {'entity': 'the Delaware Bay',
#   'label': 'LOC',
#   'explanation': 'Non-GPE locations, mountain ranges, bodies of water'},
#  {'entity': 'Pittsburgh',
#   'label': 'GPE',
#   'explanation': 'Countries, cities, states'},
#  {'entity': 'nearly 1,000',
#   'label': 'CARDINAL',
#   'explanation': 'Numerals that do not fall under another type'},
#  {'entity': 'thousands',
#   'label': 'CARDINAL',
#   'explanation': 'Numerals that do not fall under another type'},
#  {'entity': 'America',
#   'label': 'GPE',
#   'explanation': 'Countries, cities, states'},
#  {'entity': 'the \nBipartisan Infrastructure Law',
#   'label': 'LAW',
#   'explanation': 'Named documents made into laws.'},
#  {'entity': 'The \nBipartisan Infrastructure Law',
#   'label': 'LAW',
#   'explanation': 'Named documents made into laws.'},
#  {'entity': 'the Emerging \nContaminants and Smaller Disadvantaged Communities Grant',
#   'label': 'ORG',
#   'explanation': 'Companies, agencies, institutions, etc.'},
#  {'entity': 'Just a few weeks ago',
#   'label': 'DATE',
#   'explanation': 'Absolute or relative dates or periods'},
#  {'entity': 'first',
#   'label': 'ORDINAL',
#   'explanation': '"first", "second", etc.'},
#  {'entity': '$2',
#   'label': 'MONEY',
#   'explanation': 'Monetary values, including unit'},
#  {'entity': 'The Bipartisan Infrastructure Law',
#   'label': 'LAW',
#   'explanation': 'Named documents made into laws.'},
#  {'entity': 'nearly \n$2 billion',
#   'label': 'MONEY',
#   'explanation': 'Monetary values, including unit'},
#  {'entity': 'Geographic National Estuary',
#   'label': 'LOC',
#   'explanation': 'Non-GPE locations, mountain ranges, bodies of water'},
#  {'entity': 'Gulf Hypoxia',
#   'label': 'LOC',
#   'explanation': 'Non-GPE locations, mountain ranges, bodies of water'},
#  {'entity': 'the Chesapeake Bay',
#   'label': 'LOC',
#   'explanation': 'Non-GPE locations, mountain ranges, bodies of water'},
#  {'entity': 'the Great Lakes',
#   'label': 'LOC',
#   'explanation': 'Non-GPE locations, mountain ranges, bodies of water'},
#  {'entity': 'the Mississippi River',
#   'label': 'LOC',
#   'explanation': 'Non-GPE locations, mountain ranges, bodies of water'},
#  {'entity': 'the Gulf of Mexico',
#   'label': 'LOC',
#   'explanation': 'Non-GPE locations, mountain ranges, bodies of water'},
#  {'entity': 'the San Francisco Bay',
#   'label': 'LOC',
#   'explanation': 'Non-GPE locations, mountain ranges, bodies of water'},
#  {'entity': 'the Bipartisan \nInfrastructure Law',
#   'label': 'LAW',
#   'explanation': 'Named documents made into laws.'},
#  {'entity': '$50 million',
#   'label': 'MONEY',
#   'explanation': 'Monetary values, including unit'},
#  {'entity': 'States',
#   'label': 'ORG',
#   'explanation': 'Companies, agencies, institutions, etc.'},
#  {'entity': 'States',
#   'label': 'ORG',
#   'explanation': 'Companies, agencies, institutions, etc.'},
#  {'entity': 'States',
#   'label': 'ORG',
#   'explanation': 'Companies, agencies, institutions, etc.'},
#  {'entity': 'the end of this year',
#   'label': 'DATE',
#   'explanation': 'Absolute or relative dates or periods'},
#  {'entity': 'Capito',
#   'label': 'PERSON',
#   'explanation': 'People, including fictional'},
#  {'entity': 'Carper',
#   'label': 'PERSON',
#   'explanation': 'People, including fictional'},
#  {'entity': 'Federal',
#   'label': 'ORG',
#   'explanation': 'Companies, agencies, institutions, etc.'},
#  {'entity': 'EPA',
#   'label': 'ORG',
#   'explanation': 'Companies, agencies, institutions, etc.'},
#  {'entity': 'States',
#   'label': 'ORG',
#   'explanation': 'Companies, agencies, institutions, etc.'},
#  {'entity': 'McDowell County',
#   'label': 'GPE',
#   'explanation': 'Countries, cities, states'},
#  {'entity': 'West',
#   'label': 'GPE',
#   'explanation': 'Countries, cities, states'},
#  {'entity': 'Virginia',
#   'label': 'GPE',
#   'explanation': 'Countries, cities, states'},
#  {'entity': 'Lowndes County',
#   'label': 'GPE',
#   'explanation': 'Countries, cities, states'},
#  {'entity': 'Alabama',
#   'label': 'GPE',
#   'explanation': 'Countries, cities, states'},
#  {'entity': '29',
#   'label': 'CARDINAL',
#   'explanation': 'Numerals that do not fall under another type'},
#  {'entity': 'Closing the Wastewater Access Gap',
#   'label': 'WORK_OF_ART',
#   'explanation': 'Titles of books, songs, etc.'},
#  {'entity': 'Lead Service Line Accelerators',
#   'label': 'ORG',
#   'explanation': 'Companies, agencies, institutions, etc.'},
#  {'entity': 'Congress',
#   'label': 'ORG',
#   'explanation': 'Companies, agencies, institutions, etc.'},
#  {'entity': 'Biden',
#   'label': 'PERSON',
#   'explanation': 'People, including fictional'},
#  {'entity': 'EPA',
#   'label': 'ORG',
#   'explanation': 'Companies, agencies, institutions, etc.'},
#  {'entity': 'the Bipartisan Infrastructure Law',
#   'label': 'LAW',
#   'explanation': 'Named documents made into laws.'},
#  {'entity': 'Americans',
#   'label': 'NORP',
#   'explanation': 'Nationalities or religious or political groups'},
#  {'entity': 'American',
#   'label': 'NORP',
#   'explanation': 'Nationalities or religious or political groups'},
#  {'entity': 'today',
#   'label': 'DATE',
#   'explanation': 'Absolute or relative dates or periods'},
#  {'entity': 'Fox',
#   'label': 'PERSON',
#   'explanation': 'People, including fictional'},
#  {'entity': 'Carper',
#   'label': 'PERSON',
#   'explanation': 'People, including fictional'},
#  {'entity': 'today',
#   'label': 'DATE',
#   'explanation': 'Absolute or relative dates or periods'},
#  {'entity': 'EPA',
#   'label': 'ORG',
#   'explanation': 'Companies, agencies, institutions, etc.'},
#  {'entity': 'Capito',
#   'label': 'PERSON',
#   'explanation': 'People, including fictional'},
#  {'entity': 'Committee',
#   'label': 'ORG',
#   'explanation': 'Companies, agencies, institutions, etc.'},
#  {'entity': 'last week',
#   'label': 'DATE',
#   'explanation': 'Absolute or relative dates or periods'},
#  {'entity': 'East Palestine',
#   'label': 'GPE',
#   'explanation': 'Countries, cities, states'},
#  {'entity': 'East Palestine',
#   'label': 'LOC',
#   'explanation': 'Non-GPE locations, mountain ranges, bodies of water'},
#  {'entity': 'America',
#   'label': 'GPE',
#   'explanation': 'Countries, cities, states'},
#  {'entity': 'Fox',
#   'label': 'PERSON',
#   'explanation': 'People, including fictional'},
#  {'entity': 'two',
#   'label': 'CARDINAL',
#   'explanation': 'Numerals that do not fall under another type'},
#  {'entity': 'today',
#   'label': 'DATE',
#   'explanation': 'Absolute or relative dates or periods'},
#  {'entity': 'EPA',
#   'label': 'ORG',
#   'explanation': 'Companies, agencies, institutions, etc.'},
#  {'entity': 'yesterday',
#   'label': 'DATE',
#   'explanation': 'Absolute or relative dates or periods'},
#  {'entity': 'six',
#   'label': 'CARDINAL',
#   'explanation': 'Numerals that do not fall under another type'},
#  {'entity': 'Regan',
#   'label': 'PERSON',
#   'explanation': 'People, including fictional'},
#  {'entity': 'Biden',
#   'label': 'PERSON',
#   'explanation': 'People, including fictional'},
#  {'entity': 'EPA',
#   'label': 'ORG',
#   'explanation': 'Companies, agencies, institutions, etc.'},
#  {'entity': 'yesterday',
#   'label': 'DATE',
#   'explanation': 'Absolute or relative dates or periods'},
#  {'entity': 'Fox',
#   'label': 'PERSON',
#   'explanation': 'People, including fictional'},
#  {'entity': 'Fox',
#   'label': 'PERSON',
#   'explanation': 'People, including fictional'},
#  {'entity': 'Capito',
#   'label': 'PERSON',
#   'explanation': 'People, including fictional'},
#  {'entity': 'Committee',
#   'label': 'ORG',
#   'explanation': 'Companies, agencies, institutions, etc.'},
#  {'entity': 'Capito',
#   'label': 'PERSON',
#   'explanation': 'People, including fictional'},
#  {'entity': 'yesterday',
#   'label': 'DATE',
#   'explanation': 'Absolute or relative dates or periods'},
#  {'entity': 'the 2 years',
#   'label': 'DATE',
#   'explanation': 'Absolute or relative dates or periods'},
#  {'entity': 'American',
#   'label': 'NORP',
#   'explanation': 'Nationalities or religious or political groups'},
#  {'entity': 'yesterday',
#   'label': 'DATE',
#   'explanation': 'Absolute or relative dates or periods'},
#  {'entity': 'dozen',
#   'label': 'CARDINAL',
#   'explanation': 'Numerals that do not fall under another type'},
#  {'entity': 'States',
#   'label': 'GPE',
#   'explanation': 'Countries, cities, states'},
#  {'entity': 'six',
#   'label': 'CARDINAL',
#   'explanation': 'Numerals that do not fall under another type'},
#  {'entity': 'four',
#   'label': 'CARDINAL',
#   'explanation': 'Numerals that do not fall under another type'},
#  {'entity': 'trillion',
#   'label': 'CARDINAL',
#   'explanation': 'Numerals that do not fall under another type'},
#  {'entity': 'Four parts \nper trillion is',
#   'label': 'QUANTITY',
#   'explanation': 'Measurements, as of weight or distance'},
#  {'entity': 'four',
#   'label': 'CARDINAL',
#   'explanation': 'Numerals that do not fall under another type'},
#  {'entity': 'four',
#   'label': 'CARDINAL',
#   'explanation': 'Numerals that do not fall under another type'},
#  {'entity': 'four',
#   'label': 'CARDINAL',
#   'explanation': 'Numerals that do not fall under another type'},
#  {'entity': 'four',
#   'label': 'CARDINAL',
#   'explanation': 'Numerals that do not fall under another type'},
#  {'entity': 'American',
#   'label': 'NORP',
#   'explanation': 'Nationalities or religious or political groups'},
#  {'entity': '60 day',
#   'label': 'DATE',
#   'explanation': 'Absolute or relative dates or periods'},
#  {'entity': 'State',
#   'label': 'ORG',
#   'explanation': 'Companies, agencies, institutions, etc.'},
#  {'entity': '2023',
#   'label': 'DATE',
#   'explanation': 'Absolute or relative dates or periods'},
#  {'entity': '2024',
#   'label': 'DATE',
#   'explanation': 'Absolute or relative dates or periods'},
#  {'entity': 'Committee',
#   'label': 'ORG',
#   'explanation': 'Companies, agencies, institutions, etc.'},
#  {'entity': 'PFAS',
#   'label': 'ORG',
#   'explanation': 'Companies, agencies, institutions, etc.'},
#  {'entity': 'Carper',
#   'label': 'PERSON',
#   'explanation': 'People, including fictional'},
#  {'entity': 'One',
#   'label': 'CARDINAL',
#   'explanation': 'Numerals that do not fall under another type'},
#  {'entity': 'Capito',
#   'label': 'PERSON',
#   'explanation': 'People, including fictional'},
#  {'entity': 'Cramer',
#   'label': 'PERSON',
#   'explanation': 'People, including fictional'},
#  {'entity': 'Capito',
#   'label': 'PERSON',
#   'explanation': 'People, including fictional'},
#  {'entity': 'Capito',
#   'label': 'PERSON',
#   'explanation': 'People, including fictional'},
#  {'entity': 'Fox',
#   'label': 'PERSON',
#   'explanation': 'People, including fictional'},
#  {'entity': 'yesterday',
#   'label': 'DATE',
#   'explanation': 'Absolute or relative dates or periods'},
#  {'entity': 'several months ago',
#   'label': 'DATE',
#   'explanation': 'Absolute or relative dates or periods'},
#  {'entity': 'a year ago',
#   'label': 'DATE',
#   'explanation': 'Absolute or relative dates or periods'},
#  {'entity': 'EPA',
#   'label': 'ORG',
#   'explanation': 'Companies, agencies, institutions, etc.'},
#  {'entity': 'today',
#   'label': 'DATE',
#   'explanation': 'Absolute or relative dates or periods'},
#  {'entity': '4',
#   'label': 'CARDINAL',
#   'explanation': 'Numerals that do not fall under another type'},
#  {'entity': 'Yesterday',
#   'label': 'DATE',
#   'explanation': 'Absolute or relative dates or periods'},
#  {'entity': 'the day before',
#   'label': 'DATE',
#   'explanation': 'Absolute or relative dates or periods'},
#  {'entity': '1,800',
#   'label': 'CARDINAL',
#   'explanation': 'Numerals that do not fall under another type'},
#  {'entity': 'EPA',
#   'label': 'ORG',
#   'explanation': 'Companies, agencies, institutions, etc.'},
#  {'entity': 'Fox',
#   'label': 'PERSON',
#   'explanation': 'People, including fictional'},
#  {'entity': 'Capito',
#   'label': 'PERSON',
#   'explanation': 'People, including fictional'},
#  {'entity': 'CERCLA',
#   'label': 'LAW',
#   'explanation': 'Named documents made into laws.'},
#  {'entity': 'Congress',
#   'label': 'ORG',
#   'explanation': 'Companies, agencies, institutions, etc.'},
#  {'entity': 'Fox',
#   'label': 'PERSON',
#   'explanation': 'People, including fictional'},
#  {'entity': 'CERCLA',
#   'label': 'LAW',
#   'explanation': 'Named documents made into laws.'},
#  {'entity': 'Office \nof Land and Emergency Management',
#   'label': 'ORG',
#   'explanation': 'Companies, agencies, institutions, etc.'},
#  {'entity': 'one',
#   'label': 'CARDINAL',
#   'explanation': 'Numerals that do not fall under another type'},
#  {'entity': 'Office of Water',
#   'label': 'ORG',
#   'explanation': 'Companies, agencies, institutions, etc.'},
#  {'entity': 'the \nOffice of Land and Emergency Management',
#   'label': 'ORG',
#   'explanation': 'Companies, agencies, institutions, etc.'},
#  {'entity': 'CERCLA hazardous designation rule',
#   'label': 'LAW',
#   'explanation': 'Named documents made into laws.'},
#  {'entity': 'CERCLA',
#   'label': 'LAW',
#   'explanation': 'Named documents made into laws.'},
#  {'entity': 'the Bipartisan Infrastructure Law',
#   'label': 'LAW',
#   'explanation': 'Named documents made into laws.'},
#  {'entity': 'States',
#   'label': 'ORG',
#   'explanation': 'Companies, agencies, institutions, etc.'},
#  {'entity': '$9 billion',
#   'label': 'MONEY',
#   'explanation': 'Monetary values, including unit'},
#  {'entity': 'Capito',
#   'label': 'PERSON',
#   'explanation': 'People, including fictional'},
#  {'entity': 'DC', 'label': 'GPE', 'explanation': 'Countries, cities, states'},
#  {'entity': 'States',
#   'label': 'GPE',
#   'explanation': 'Countries, cities, states'},
#  {'entity': 'West Virginia',
#   'label': 'GPE',
#   'explanation': 'Countries, cities, states'},
#  {'entity': 'Fox',
#   'label': 'PERSON',
#   'explanation': 'People, including fictional'},
#  {'entity': 'the Bipartisan \nInfrastructure Law',
#   'label': 'LAW',
#   'explanation': 'Named documents made into laws.'},
#  {'entity': 'States',
#   'label': 'ORG',
#   'explanation': 'Companies, agencies, institutions, etc.'},
#  {'entity': 'Capito',
#   'label': 'PERSON',
#   'explanation': 'People, including fictional'},
#  {'entity': 'thousands',
#   'label': 'CARDINAL',
#   'explanation': 'Numerals that do not fall under another type'},
#  {'entity': 'One',
#   'label': 'CARDINAL',
#   'explanation': 'Numerals that do not fall under another type'},
#  {'entity': 'SRF',
#   'label': 'LAW',
#   'explanation': 'Named documents made into laws.'},
#  {'entity': 'Clean Water SRF',
#   'label': 'LAW',
#   'explanation': 'Named documents made into laws.'},
#  {'entity': 'Drinking Water SRF',
#   'label': 'LAW',
#   'explanation': 'Named documents made into laws.'},
#  {'entity': 'States',
#   'label': 'ORG',
#   'explanation': 'Companies, agencies, institutions, etc.'},
#  {'entity': 'the \nSafe Drinking Water Act',
#   'label': 'LAW',
#   'explanation': 'Named documents made into laws.'},
#  {'entity': 'Clean Water Act',
#   'label': 'LAW',
#   'explanation': 'Named documents made into laws.'},
#  {'entity': 'Capito',
#   'label': 'PERSON',
#   'explanation': 'People, including fictional'},
#  {'entity': 'States',
#   'label': 'GPE',
#   'explanation': 'Countries, cities, states'},
#  {'entity': 'EPA',
#   'label': 'ORG',
#   'explanation': 'Companies, agencies, institutions, etc.'},
#  {'entity': 'Transportation',
#   'label': 'ORG',
# ...
#   'label': 'LAW',
#   'explanation': 'Named documents made into laws.'},
#  {'entity': 'Fox',
#   'label': 'PERSON',
#   'explanation': 'People, including fictional'},
#  {'entity': 'Congress',
#   'label': 'ORG',
#   'explanation': 'Companies, agencies, institutions, etc.'},
#  {'entity': 'Federal',
#   'label': 'ORG',
#   'explanation': 'Companies, agencies, institutions, etc.'},
#  {'entity': 'Biden',
#   'label': 'PERSON',
#   'explanation': 'People, including fictional'},
#  {'entity': 'Justice 40',
#   'label': 'LAW',
#   'explanation': 'Named documents made into laws.'},
#  {'entity': 'EPA',
#   'label': 'ORG',
#   'explanation': 'Companies, agencies, institutions, etc.'},
#  {'entity': 'Federal',
#   'label': 'ORG',
#   'explanation': 'Companies, agencies, institutions, etc.'},
#  {'entity': 'Fox',
#   'label': 'PERSON',
#   'explanation': 'People, including fictional'},
#  {'entity': 'States',
#   'label': 'GPE',
#   'explanation': 'Countries, cities, states'},
#  {'entity': 'CIFA',
#   'label': 'ORG',
#   'explanation': 'Companies, agencies, institutions, etc.'},
#  {'entity': 'the Council of Infrastructure \nFinancing Authorities',
#   'label': 'ORG',
#   'explanation': 'Companies, agencies, institutions, etc.'},
#  {'entity': 'EPA',
#   'label': 'ORG',
#   'explanation': 'Companies, agencies, institutions, etc.'},
#  {'entity': 'States',
#   'label': 'GPE',
#   'explanation': 'Countries, cities, states'},
#  {'entity': 'States',
#   'label': 'GPE',
#   'explanation': 'Countries, cities, states'},
#  {'entity': 'annual',
#   'label': 'DATE',
#   'explanation': 'Absolute or relative dates or periods'},
#  {'entity': 'States',
#   'label': 'GPE',
#   'explanation': 'Countries, cities, states'},
#  {'entity': 'the Federal',
#   'label': 'ORG',
#   'explanation': 'Companies, agencies, institutions, etc.'},
#  {'entity': 'One',
#   'label': 'CARDINAL',
#   'explanation': 'Numerals that do not fall under another type'},
#  {'entity': 'States',
#   'label': 'GPE',
#   'explanation': 'Countries, cities, states'},
#  {'entity': 'States',
#   'label': 'GPE',
#   'explanation': 'Countries, cities, states'},
#  {'entity': 'Carper',
#   'label': 'PERSON',
#   'explanation': 'People, including fictional'},
#  {'entity': 'One',
#   'label': 'CARDINAL',
#   'explanation': 'Numerals that do not fall under another type'},
#  {'entity': 'Biden',
#   'label': 'PERSON',
#   'explanation': 'People, including fictional'},
#  {'entity': 'The Bipartisan Infrastructure Law',
#   'label': 'LAW',
#   'explanation': 'Named documents made into laws.'},
#  {'entity': '$15 billion',
#   'label': 'MONEY',
#   'explanation': 'Monetary values, including unit'},
#  {'entity': 'the years',
#   'label': 'DATE',
#   'explanation': 'Absolute or relative dates or periods'},
#  {'entity': 'States',
#   'label': 'GPE',
#   'explanation': 'Countries, cities, states'},
#  {'entity': 'Delaware',
#   'label': 'GPE',
#   'explanation': 'Countries, cities, states'},
#  {'entity': 'States',
#   'label': 'GPE',
#   'explanation': 'Countries, cities, states'},
#  {'entity': 'States',
#   'label': 'GPE',
#   'explanation': 'Countries, cities, states'},
#  {'entity': 'Fox',
#   'label': 'PERSON',
#   'explanation': 'People, including fictional'},
#  {'entity': 'One',
#   'label': 'CARDINAL',
#   'explanation': 'Numerals that do not fall under another type'},
#  {'entity': 'Biden',
#   'label': 'PERSON',
#   'explanation': 'People, including fictional'},
#  {'entity': 'EPA',
#   'label': 'ORG',
#   'explanation': 'Companies, agencies, institutions, etc.'},
#  {'entity': 'States',
#   'label': 'GPE',
#   'explanation': 'Countries, cities, states'},
#  {'entity': '2 years',
#   'label': 'DATE',
#   'explanation': 'Absolute or relative dates or periods'},
#  {'entity': 'first',
#   'label': 'ORDINAL',
#   'explanation': '"first", "second", etc.'},
#  {'entity': 'those 2 years',
#   'label': 'DATE',
#   'explanation': 'Absolute or relative dates or periods'},
#  {'entity': 'States',
#   'label': 'ORG',
#   'explanation': 'Companies, agencies, institutions, etc.'},
#  {'entity': 'Carper',
#   'label': 'PERSON',
#   'explanation': 'People, including fictional'},
#  {'entity': 'today',
#   'label': 'DATE',
#   'explanation': 'Absolute or relative dates or periods'},
#  {'entity': 'West Virginia',
#   'label': 'GPE',
#   'explanation': 'Countries, cities, states'},
#  {'entity': 'Virginia',
#   'label': 'GPE',
#   'explanation': 'Countries, cities, states'},
#  {'entity': 'Delaware',
#   'label': 'GPE',
#   'explanation': 'Countries, cities, states'},
#  {'entity': 'about 173,000',
#   'label': 'CARDINAL',
#   'explanation': 'Numerals that do not fall under another type'},
#  {'entity': 'Delaware',
#   'label': 'GPE',
#   'explanation': 'Countries, cities, states'},
#  {'entity': 'a million',
#   'label': 'CARDINAL',
#   'explanation': 'Numerals that do not fall under another type'},
#  {'entity': 'about 173,000',
#   'label': 'CARDINAL',
#   'explanation': 'Numerals that do not fall under another type'},
#  {'entity': 'Congress',
#   'label': 'ORG',
#   'explanation': 'Companies, agencies, institutions, etc.'},
#  {'entity': 'the Drinking Water and \nWastewater Infrastructure Act',
#   'label': 'LAW',
#   'explanation': 'Named documents made into laws.'},
#  {'entity': 'EPA',
#   'label': 'ORG',
#   'explanation': 'Companies, agencies, institutions, etc.'},
#  {'entity': 'States',
#   'label': 'GPE',
#   'explanation': 'Countries, cities, states'},
#  {'entity': 'EPA',
#   'label': 'ORG',
#   'explanation': 'Companies, agencies, institutions, etc.'},
#  {'entity': 'States',
#   'label': 'ORG',
#   'explanation': 'Companies, agencies, institutions, etc.'},
#  {'entity': 'Congress',
#   'label': 'ORG',
#   'explanation': 'Companies, agencies, institutions, etc.'},
#  {'entity': 'EPA',
#   'label': 'ORG',
#   'explanation': 'Companies, agencies, institutions, etc.'},
#  {'entity': 'the Safe \nDrinking Water Act',
#   'label': 'LAW',
#   'explanation': 'Named documents made into laws.'},
#  {'entity': 'Congress',
#   'label': 'ORG',
#   'explanation': 'Companies, agencies, institutions, etc.'},
#  {'entity': 'EPA',
#   'label': 'ORG',
#   'explanation': 'Companies, agencies, institutions, etc.'},
#  {'entity': 'States',
#   'label': 'ORG',
#   'explanation': 'Companies, agencies, institutions, etc.'},
#  {'entity': 'today',
#   'label': 'DATE',
#   'explanation': 'Absolute or relative dates or periods'},
#  {'entity': 'this Committee on the Environment and Public \nWorks',
#   'label': 'ORG',
#   'explanation': 'Companies, agencies, institutions, etc.'},
#  {'entity': 'Fox',
#   'label': 'PERSON',
#   'explanation': 'People, including fictional'},
#  {'entity': 'Committee',
#   'label': 'ORG',
#   'explanation': 'Companies, agencies, institutions, etc.'},
#  {'entity': 'Carper',
#   'label': 'PERSON',
#   'explanation': 'People, including fictional'},
#  {'entity': 'Fox',
#   'label': 'PERSON',
#   'explanation': 'People, including fictional'},
#  {'entity': 'Carper',
#   'label': 'PERSON',
#   'explanation': 'People, including fictional'},
#  {'entity': 'Fox',
#   'label': 'PERSON',
#   'explanation': 'People, including fictional'},
#  {'entity': 'The Pacific Ocean',
#   'label': 'LOC',
#   'explanation': 'Non-GPE locations, mountain ranges, bodies of water'},
#  {'entity': 'Carper',
#   'label': 'PERSON',
#   'explanation': 'People, including fictional'},
#  {'entity': 'today',
#   'label': 'DATE',
#   'explanation': 'Absolute or relative dates or periods'},
#  {'entity': 'Navy',
#   'label': 'ORG',
#   'explanation': 'Companies, agencies, institutions, etc.'},
#  {'entity': 'Moffett Field Naval \nAir Station',
#   'label': 'FAC',
#   'explanation': 'Buildings, airports, highways, bridges, etc.'},
#  {'entity': 'two',
#   'label': 'CARDINAL',
#   'explanation': 'Numerals that do not fall under another type'},
#  {'entity': 'NASA',
#   'label': 'ORG',
#   'explanation': 'Companies, agencies, institutions, etc.'},
#  {'entity': 'P3s',
#   'label': 'PRODUCT',
#   'explanation': 'Objects, vehicles, foods, etc. (not services)'},
#  {'entity': 'four',
#   'label': 'CARDINAL',
#   'explanation': 'Numerals that do not fall under another type'},
#  {'entity': 'NASA',
#   'label': 'ORG',
#   'explanation': 'Companies, agencies, institutions, etc.'},
#  {'entity': 'Early one morning',
#   'label': 'TIME',
#   'explanation': 'Times smaller than a day'},
#  {'entity': 'two',
#   'label': 'CARDINAL',
#   'explanation': 'Numerals that do not fall under another type'},
#  {'entity': 'two',
#   'label': 'CARDINAL',
#   'explanation': 'Numerals that do not fall under another type'},
#  {'entity': 'Navy',
#   'label': 'ORG',
#   'explanation': 'Companies, agencies, institutions, etc.'},
#  {'entity': 'P3',
#   'label': 'PRODUCT',
#   'explanation': 'Objects, vehicles, foods, etc. (not services)'},
#  {'entity': 'NASA',
#   'label': 'ORG',
#   'explanation': 'Companies, agencies, institutions, etc.'},
#  {'entity': 'NASA',
#   'label': 'ORG',
#   'explanation': 'Companies, agencies, institutions, etc.'},
#  {'entity': 'P3',
#   'label': 'PRODUCT',
#   'explanation': 'Objects, vehicles, foods, etc. (not services)'},
#  {'entity': 'about 18',
#   'label': 'CARDINAL',
#   'explanation': 'Numerals that do not fall under another type'},
#  {'entity': '18',
#   'label': 'CARDINAL',
#   'explanation': 'Numerals that do not fall under another type'},
#  {'entity': 'About 28 years later',
#   'label': 'DATE',
#   'explanation': 'Absolute or relative dates or periods'},
#  {'entity': 'Delaware',
#   'label': 'GPE',
#   'explanation': 'Countries, cities, states'},
#  {'entity': 'Rehobeth',
#   'label': 'GPE',
#   'explanation': 'Countries, cities, states'},
#  {'entity': 'Dover \nAir Force Base',
#   'label': 'FAC',
#   'explanation': 'Buildings, airports, highways, bridges, etc.'},
#  {'entity': 'Route \n1',
#   'label': 'FAC',
#   'explanation': 'Buildings, airports, highways, bridges, etc.'},
#  {'entity': 'the Air Force Base',
#   'label': 'FAC',
#   'explanation': 'Buildings, airports, highways, bridges, etc.'},
#  {'entity': 'C5',
#   'label': 'PRODUCT',
#   'explanation': 'Objects, vehicles, foods, etc. (not services)'},
#  {'entity': 'Dover Air Force Base',
#   'label': 'FAC',
#   'explanation': 'Buildings, airports, highways, bridges, etc.'},
#  {'entity': 'four',
#   'label': 'CARDINAL',
#   'explanation': 'Numerals that do not fall under another type'},
#  {'entity': 'C5',
#   'label': 'PRODUCT',
#   'explanation': 'Objects, vehicles, foods, etc. (not services)'},
#  {'entity': 'one',
#   'label': 'CARDINAL',
#   'explanation': 'Numerals that do not fall under another type'},
#  {'entity': 'four',
#   'label': 'CARDINAL',
#   'explanation': 'Numerals that do not fall under another type'},
#  {'entity': 'four',
#   'label': 'CARDINAL',
#   'explanation': 'Numerals that do not fall under another type'},
#  {'entity': 'two',
#   'label': 'CARDINAL',
#   'explanation': 'Numerals that do not fall under another type'},
#  {'entity': 'about a mile',
#   'label': 'QUANTITY',
#   'explanation': 'Measurements, as of weight or distance'},
#  {'entity': 'the Dover Air Force \nBase',
#   'label': 'FAC',
#   'explanation': 'Buildings, airports, highways, bridges, etc.'},
#  {'entity': 'four',
#   'label': 'CARDINAL',
#   'explanation': 'Numerals that do not fall under another type'},
#  {'entity': 'Dover Air Force Base',
#   'label': 'FAC',
#   'explanation': 'Buildings, airports, highways, bridges, etc.'},
#  {'entity': 'Delaware',
#   'label': 'GPE',
#   'explanation': 'Countries, cities, states'},
#  {'entity': 'West',
#   'label': 'GPE',
#   'explanation': 'Countries, cities, states'},
#  {'entity': 'Virginia',
#   'label': 'GPE',
#   'explanation': 'Countries, cities, states'},
#  {'entity': 'Capito',
#   'label': 'PERSON',
#   'explanation': 'People, including fictional'},
#  {'entity': 'Capito',
#   'label': 'PERSON',
#   'explanation': 'People, including fictional'},
#  {'entity': 'Carper',
#   'label': 'PERSON',
#   'explanation': 'People, including fictional'},
#  {'entity': 'second',
#   'label': 'ORDINAL',
#   'explanation': '"first", "second", etc.'},
#  {'entity': 'Good morning',
#   'label': 'TIME',
#   'explanation': 'Times smaller than a day'},
#  {'entity': 'Randy Hayman',
#   'label': 'PERSON',
#   'explanation': 'People, including fictional'},
#  {'entity': 'the Philadelphia \nWater Department',
#   'label': 'ORG',
#   'explanation': 'Companies, agencies, institutions, etc.'},
#  {'entity': '2019',
#   'label': 'DATE',
#   'explanation': 'Absolute or relative dates or periods'},
#  {'entity': 'Jim Kenney',
#   'label': 'PERSON',
#   'explanation': 'People, including fictional'},
#  {'entity': 'today',
#   'label': 'DATE',
#   'explanation': 'Absolute or relative dates or periods'},
#  {'entity': 'RANDY E. HAYMAN',
#   'label': 'PERSON',
#   'explanation': 'People, including fictional'},
#  {'entity': 'PHILADELPHIA WATER DEPARTMENT',
#   'label': 'ORG',
#   'explanation': 'Companies, agencies, institutions, etc.'},
#  {'entity': 'Hayman',
#   'label': 'PERSON',
#   'explanation': 'People, including fictional'},
#  {'entity': 'Carper',
#   'label': 'PERSON',
#   'explanation': 'People, including fictional'},
#  {'entity': 'Capito',
#   'label': 'PERSON',
#   'explanation': 'People, including fictional'},
#  {'entity': 'Committee',
#   'label': 'ORG',
#   'explanation': 'Companies, agencies, institutions, etc.'},
#  {'entity': 'the Infrastructure Investment and \nJobs Act',
#   'label': 'LAW',
#   'explanation': 'Named documents made into laws.'},
#  {'entity': 'the Drinking Water and Wastewater Infrastructure \nAct',
#   'label': 'LAW',
#   'explanation': 'Named documents made into laws.'},
#  {'entity': 'the Bipartisan Infrastructure Law',
#   'label': 'LAW',
#   'explanation': 'Named documents made into laws.'},
#  {'entity': 'the Philadelphia Water \nDepartment',
#   'label': 'ORG',
#   'explanation': 'Companies, agencies, institutions, etc.'},
#  {'entity': 'the Board of Directors',
#   'label': 'ORG',
#   'explanation': 'Companies, agencies, institutions, etc.'},
#  {'entity': 'the \nAssociation of Metropolitan Water Agencies',
#   'label': 'ORG',
#   'explanation': 'Companies, agencies, institutions, etc.'},
#  {'entity': 'Committee',
#   'label': 'ORG',
#   'explanation': 'Companies, agencies, institutions, etc.'},
#  {'entity': 'Drinking \nWater',
#   'label': 'LAW',
#   'explanation': 'Named documents made into laws.'},
#  {'entity': 'BIL',
#   'label': 'LAW',
#   'explanation': 'Named documents made into laws.'},
#  {'entity': 'AMWA',
#   'label': 'ORG',
#   'explanation': 'Companies, agencies, institutions, etc.'},
#  {'entity': 'DWWIA',
#   'label': 'LAW',
#   'explanation': 'Named documents made into laws.'},
#  {'entity': 'the Drinking Water and Wastewater \nInfrastructure Act',
#   'label': 'LAW',
#   'explanation': 'Named documents made into laws.'},
#  {'entity': 'Senate',
#   'label': 'ORG',
#   'explanation': 'Companies, agencies, institutions, etc.'},
#  {'entity': '89',
#   'label': 'CARDINAL',
#   'explanation': 'Numerals that do not fall under another type'},
#  {'entity': '2',
#   'label': 'CARDINAL',
#   'explanation': 'Numerals that do not fall under another type'},
#  {'entity': 'the Infrastructure Law',
#   'label': 'LAW',
#   'explanation': 'Named documents made into laws.'},
#  {'entity': '2019',
#   'label': 'DATE',
#   'explanation': 'Absolute or relative dates or periods'},
#  {'entity': 'Philadelphia',
#   'label': 'GPE',
#   'explanation': 'Countries, cities, states'},
#  {'entity': '25 year',
#   'label': 'DATE',
#   'explanation': 'Absolute or relative dates or periods'},
#  {'entity': 'multi-billion dollar',
#   'label': 'MONEY',
#   'explanation': 'Monetary values, including unit'},
#  {'entity': 'an estimated 400',
#   'label': 'CARDINAL',
#   'explanation': 'Numerals that do not fall under another type'},
#  {'entity': 'DWWIA',
#   'label': 'LAW',
#   'explanation': 'Named documents made into laws.'},
#  {'entity': 'last month',
#   'label': 'DATE',
#   'explanation': 'Absolute or relative dates or periods'},
#  {'entity': 'Biden',
#   'label': 'PERSON',
#   'explanation': 'People, including fictional'},
#  {'entity': 'Philadelphia',
#   'label': 'GPE',
#   'explanation': 'Countries, cities, states'},
#  {'entity': '$500 million',
#   'label': 'MONEY',
#   'explanation': 'Monetary values, including unit'},
#  {'entity': 'Carper',
#   'label': 'PERSON',
#   'explanation': 'People, including fictional'},
#  {'entity': 'Hayman',
#   'label': 'PERSON',
#   'explanation': 'People, including fictional'},
#  {'entity': 'Five hundred million',
#   'label': 'MONEY',
#   'explanation': 'Monetary values, including unit'},
#  {'entity': '$160 million',
#   'label': 'MONEY',
#   'explanation': 'Monetary values, including unit'},
#  ...]

# %%
df = pd.DataFrame(hearing_data)
df
# Out:
#                                              entity label  \
# 0                                          MARCH 15  DATE
# 1     the Committee on Environment and Public Works   ORG
# 2                                the World Wide Web   ORG
# 3                                        WASHINGTON   GPE
# 4                                        EIGHTEENTH  DATE
# ...                                             ...   ...
# 1488                                        Packers   ORG
# 1489                                         Eagles   ORG
# 1490                                      the years  DATE
# 1491                                          Green   GPE
# 1492                                     12:27 p.m.  TIME
#
#                                   explanation
# 0       Absolute or relative dates or periods
# 1     Companies, agencies, institutions, etc.
# 2     Companies, agencies, institutions, etc.
# 3                   Countries, cities, states
# 4       Absolute or relative dates or periods
# ...                                       ...
# 1488  Companies, agencies, institutions, etc.
# 1489  Companies, agencies, institutions, etc.
# 1490    Absolute or relative dates or periods
# 1491                Countries, cities, states
# 1492                 Times smaller than a day
#
# [1493 rows x 3 columns]

# %%
df.to_csv("senate-hearing-keywords.csv", encoding="utf-8", index=False)
